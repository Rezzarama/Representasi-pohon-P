# %% [markdown]
# <a href="https://colab.research.google.com/github/Rezzarama/Representasi-pohon-P/blob/main/Representasi__pengetahuan_pohon_keluarga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Membuat graf kosong untuk pohon keluarga
G = nx.DiGraph()

# Menambahkan node ke dalam graf sesuai pohon keluarga
nodes = {
    "Hadi": (0, 4), "Retno": (2, 4),
    "Bayu": (-2, 3), "Desi": (0, 3), "Rezza": (2, 3),
    "Rina": (4, 3), "Ardi": (6, 3), "Fahlevi": (8, 3),
    "Fahrul": (-2, 2), "Tari": (0, 2), "Nurul": (1, 2),
    "Yanto": (3, 2), "Hamzah": (5, 2),
    "Eka": (4, 2), "Mira": (6, 2), "Bastian": (7, 2),
    "Wanda": (-2, 1), "Aji": (1, 1), "Gunawan": (3, 1),
    "Anggun": (5, 1), "Boy": (7, 1)
}

# Tambahkan node ke graf
for name, pos in nodes.items():
    G.add_node(name, pos=pos)

# Mendapatkan posisi node
pos = nx.get_node_attributes(G, 'pos')

# Menggambar graf tanpa garis penghubung (edges)
plt.figure(figsize=(12, 8))
nx.draw_networkx_nodes(G, pos, node_size=3000, node_color="lightblue")
nx.draw_networkx_labels(G, pos, font_size=10, font_weight="bold")
plt.title("Pohon Keluarga Sederhana", fontsize=14)
plt.axis('off')  # Menghapus sumbu
plt.show()
